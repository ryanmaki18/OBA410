# %% [markdown]
# # provided code

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
# reading the data
cancer=pd.read_csv('breast_cancer_data.csv',index_col=0)
cancer.head(2)
# Out:
#        diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 842302         M        17.99         10.38           122.8     1001.0
# 842517         M        20.57         17.77           132.9     1326.0
#
#         smoothness_mean  compactness_mean  concavity_mean  \
# id
# 842302          0.11840           0.27760          0.3001
# 842517          0.08474           0.07864          0.0869
#
#         concave points_mean  symmetry_mean  ...  radius_worst  texture_worst  \
# id                                          ...
# 842302              0.14710         0.2419  ...         25.38          17.33
# 842517              0.07017         0.1812  ...         24.99          23.41
#
#         perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# id
# 842302            184.6      2019.0            0.1622             0.6656
# 842517            158.8      1956.0            0.1238             0.1866
#
# ...

# %%
# creating features and target
X_cancer, y_cancer=cancer.iloc[:,1:], cancer['diagnosis']
X_cancer.head(2)
# Out:
#         radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# id
# 842302        17.99         10.38           122.8     1001.0          0.11840
# 842517        20.57         17.77           132.9     1326.0          0.08474
#
#         compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# id
# 842302           0.27760          0.3001              0.14710         0.2419
# 842517           0.07864          0.0869              0.07017         0.1812
#
#         fractal_dimension_mean  ...  radius_worst  texture_worst  \
# id                              ...
# 842302                 0.07871  ...         25.38          17.33
# 842517                 0.05667  ...         24.99          23.41
#
#         perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# id
# 842302            184.6      2019.0            0.1622             0.6656
# 842517            158.8      1956.0            0.1238             0.1866
#
# ...

# %%
# split to train and test
X_train, X_test, y_train, y_test=train_test_split(X_cancer, y_cancer, random_state=0)

# %% [markdown]
# # Random Forest Model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# define and fit the model
rf1=RandomForestClassifier(n_estimators=200, random_state=3)
rf1.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=3)

# %%
# evaluate the performance
print('rf1 on train: {:.2%}'.format(rf1.score(X_train, y_train)))
print('rf1 on test: {:.2%}'.format(rf1.score(X_test, y_test)))
# Out:
# rf1 on train: 100.00%
# rf1 on test: 97.20%

# %%
rf1.feature_importances_
# Out:
# array([0.03561676, 0.01343467, 0.04250692, 0.02468547, 0.00563106,
#        0.01252286, 0.05855396, 0.13043036, 0.00501132, 0.00415903,
#        0.01562678, 0.00516189, 0.01716373, 0.0306786 , 0.00400864,
#        0.0054022 , 0.00555898, 0.00637716, 0.00431409, 0.0058542 ,
#        0.1098942 , 0.02344538, 0.1378885 , 0.09051865, 0.01303021,
#        0.02084424, 0.03162124, 0.12361188, 0.00961901, 0.006828  ])

# %%
rf_feat_imp=pd.DataFrame(data=rf1.feature_importances_, index=X_cancer.columns, columns=['importance'])
rf_feat_imp.sort_values(by=['importance'], ascending=False)
# Out:
#                          importance
# perimeter_worst            0.137888
# concave points_mean        0.130430
# concave points_worst       0.123612
# radius_worst               0.109894
# area_worst                 0.090519
# concavity_mean             0.058554
# perimeter_mean             0.042507
# radius_mean                0.035617
# concavity_worst            0.031621
# area_se                    0.030679
# area_mean                  0.024685
# texture_worst              0.023445
# compactness_worst          0.020844
# perimeter_se               0.017164
# radius_se                  0.015627
# texture_mean               0.013435
# smoothness_worst           0.013030
# compactness_mean           0.012523
# symmetry_worst             0.009619
# fractal_dimension_worst    0.006828
# concave points_se          0.006377
# fractal_dimension_se       0.005854
# smoothness_mean            0.005631
# concavity_se               0.005559
# compactness_se             0.005402
# ...
